# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels
# %matplotlib inline

# %%
# Figure 20.1
data = pd.read_csv("./data/TableF20-1.txt", sep='\s+')

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data.plot()
